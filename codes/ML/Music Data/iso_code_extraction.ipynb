# %%
import requests
from bs4 import BeautifulSoup
from pymongo import MongoClient

# %%
def scrape_iso_codes(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    table = soup.find('table', {'class': 'wikitable sortable'})
    rows = table.find_all('tr')
    country_data = []

    for row in rows[1:]:  # Skip the header row
        cols = row.find_all('td')
        if len(cols) >= 4:
            code = cols[0].text.strip()
            country_name = cols[1].text.strip()
            year = cols[2].text.strip()
            cctld = cols[3].text.strip()
            country_data.append({"code": code, "country_name": country_name, "year": year, "cctld": cctld})

    return country_data

# %%
# URL of the Wikipedia page
url = 'https://en.wikipedia.org/wiki/ISO_3166-1_alpha-2#Officially_assigned_code_elements'

# Scrape the data
data = scrape_iso_codes(url)

# Print the scraped data
for item in data:
    print(item)
# Out:
# {'code': 'AD', 'country_name': 'Andorra', 'year': '1974', 'cctld': '.ad'}
# {'code': 'AE', 'country_name': 'United Arab Emirates', 'year': '1974', 'cctld': '.ae'}
# {'code': 'AF', 'country_name': 'Afghanistan', 'year': '1974', 'cctld': '.af'}
# {'code': 'AG', 'country_name': 'Antigua and Barbuda', 'year': '1974', 'cctld': '.ag'}
# {'code': 'AI', 'country_name': 'Anguilla', 'year': '1985', 'cctld': '.ai'}
# {'code': 'AL', 'country_name': 'Albania', 'year': '1974', 'cctld': '.al'}
# {'code': 'AM', 'country_name': 'Armenia', 'year': '1992', 'cctld': '.am'}
# {'code': 'AO', 'country_name': 'Angola', 'year': '1974', 'cctld': '.ao'}
# {'code': 'AQ', 'country_name': 'Antarctica', 'year': '1974', 'cctld': '.aq'}
# {'code': 'AR', 'country_name': 'Argentina', 'year': '1974', 'cctld': '.ar'}
# {'code': 'AS', 'country_name': 'American Samoa', 'year': '1974', 'cctld': '.as'}
# {'code': 'AT', 'country_name': 'Austria', 'year': '1974', 'cctld': '.at'}
# ...

# %%
# MongoDB database and collection names
user = "admin"
password = "g41WZadbgsPmC37B"
uri = f"mongodb+srv://{user}:{password}@rpm.spzvwtw.mongodb.net/"

db_name = 'RecognitivePretrainedModels'
collection_name = 'ISO_CODE'

client = MongoClient(uri)
db = client[db_name]
collection = db[collection_name]
collection.insert_many(data)

print("Data saved to MongoDB successfully.")
# Out:
# Data saved to MongoDB successfully.
